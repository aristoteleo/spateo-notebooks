# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'
import sys
from pathlib import Path
import anndata as ad
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import seaborn as sns
from matplotlib import pyplot as plt

sys.path.insert(0, "/home/ylu/project/spateo-release_new")
import spateo_dev as st
sys.path.insert(0, "/home/ylu/project")
from utils import *
import os

os.system('/usr/bin/Xvfb :99 -screen 0 1024x768x24 &')
os.environ['DISPLAY'] = ':99'

# %load_ext autoreload
# %autoreload 2
# Out:
# 2024-08-17 23:43:53.916940: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-17 23:43:54.091841: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-08-17 23:43:54.091867: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-08-17 23:43:54.780216: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-08-17 23:43:54.780305: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-08-17 23:43:54.780313: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (EE)
# Fatal server error:
# (EE) Server is already active for display 99
# 	If this server is no longer running, remove /tmp/.X99-lock
# 	and start again.
# (EE)

# %%
method_name = 'Moscot'
# ori_results_folder = ""
data_folder = f"./global_results/{method_name}/"
results_folder = f"./global_results/{method_name}_global/"
if not os.path.exists(results_folder):
    os.mkdir(results_folder)

# %%
for i in range(16):
    # i = 1
    # data_name = "sagittal{}".format(i)
    data_name = "well_{:02d}".format(i)
    cur_data_folder = os.path.join(data_folder, data_name)
    s = ad.read_h5ad(os.path.join(data_folder, data_name + '.h5ad'))
    slices = [s[s.obs['slice_id'] == str(i)] for i in range(10)]
    key_added = "global_align_spatial"
    global_align_slices = st.align.morpho_global_optimization(
        models=slices,
        spatial_key='align_spatial',
        key_added="global_align_spatial",
        device="3",
        mode="SN-S",
        max_iter_global=5,
        max_iter=200,
        verbose=False,
        partial_robust_level=50,
        beta=1e-4,
        lambdaVF=1e4,
        vis_optimization=False,
        fps=10,
        stepsize=4,
        batch_size=4000,
        nonrigid_idx=None,
        neighbor_size=2,
    )
        
    stacked_slices = ad.concat(global_align_slices, axis=0, label='slice_id')
    stacked_slices.write_h5ad(os.path.join(results_folder, data_name+'.h5ad'))
# Out:
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:01<00:06,  1.20it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:03<00:10,  1.43s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:07<00:13,  2.22s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:10<00:12,  2.46s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:14<00:11,  2.92s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:20<00:11,  3.87s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:27<00:09,  4.94s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:31<00:04,  4.82s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:37<00:00,  3.78s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:08<01:15,  8.44s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:17<01:08,  8.54s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:19<00:41,  5.87s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:27<00:39,  6.57s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:29<00:24,  4.80s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:38<00:24,  6.21s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:47<00:21,  7.13s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:51<00:12,  6.21s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:58<00:06,  6.67s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:04<00:00,  6.44s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:07<01:09,  7.73s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:15<01:03,  7.89s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:23<00:53,  7.66s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:29<00:43,  7.32s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:37<00:36,  7.27s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:42<00:26,  6.73s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:50<00:21,  7.09s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:56<00:13,  6.66s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:02<00:06,  6.51s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:12<00:00,  7.21s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:09<01:23,  9.28s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:14<00:55,  6.94s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:19<00:42,  6.14s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:24<00:34,  5.73s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:34<00:35,  7.08s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:42<00:30,  7.57s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:49<00:22,  7.34s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:57<00:14,  7.44s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:05<00:07,  7.70s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:08<00:00,  6.83s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:09<01:27,  9.72s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:16<01:01,  7.73s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:25<00:59,  8.56s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:32<00:47,  7.94s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:40<00:39,  7.81s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:49<00:32,  8.24s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:54<00:22,  7.37s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:01<00:14,  7.09s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:04<00:05,  5.74s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:07<00:00,  6.72s/it]
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
# Global optimization successfully!
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:05<00:22,  2.84s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:14<00:35,  5.13s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:19<00:31,  5.31s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:25<00:27,  5.42s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:31<00:22,  5.62s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:35<00:15,  5.10s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:38<00:09,  4.62s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:44<00:04,  4.99s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:49<00:00,  4.99s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:08<01:14,  8.23s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:13<00:52,  6.52s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:23<00:56,  8.08s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:30<00:45,  7.65s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:37<00:37,  7.46s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:44<00:29,  7.39s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:49<00:19,  6.44s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:55<00:12,  6.45s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:57<00:05,  5.11s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:06<00:00,  6.66s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:06<01:00,  6.76s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:15<01:05,  8.19s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:24<00:59,  8.45s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:28<00:40,  6.77s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:36<00:35,  7.03s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:45<00:30,  7.69s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:55<00:25,  8.47s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:01<00:15,  7.62s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:10<00:08,  8.24s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:18<00:00,  7.80s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:00<00:07,  1.14it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:09<00:45,  5.70s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:17<00:45,  6.49s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:27<00:47,  7.89s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:34<00:38,  7.75s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:43<00:32,  8.08s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:53<00:25,  8.65s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:01<00:16,  8.40s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:10<00:08,  8.62s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:18<00:00,  7.82s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:09<01:25,  9.46s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:17<01:06,  8.37s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:26<01:01,  8.86s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:37<00:57,  9.54s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:45<00:45,  9.03s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:55<00:38,  9.61s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [01:04<00:27,  9.15s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:14<00:19,  9.55s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:23<00:09,  9.21s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:31<00:00,  9.10s/it]
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# ...
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:35<00:53,  8.88s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:51<00:56, 11.26s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [01:09<00:54, 13.73s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [01:15<00:32, 10.96s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:31<00:25, 12.58s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:48<00:13, 13.95s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [02:06<00:00, 12.70s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:04<00:41,  4.61s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:26<01:58, 14.82s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:30<01:08,  9.76s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:35<00:48,  8.07s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:42<00:37,  7.52s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:57<00:40, 10.16s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:59<00:22,  7.58s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:21<00:23, 11.95s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:28<00:10, 10.36s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:32<00:00,  9.20s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:03<00:29,  3.30s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:08<00:35,  4.44s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:23<01:05,  9.32s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:26<00:41,  6.89s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:29<00:26,  5.38s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:35<00:21,  5.44s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:55<00:30, 10.21s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:59<00:16,  8.41s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:14<00:10, 10.49s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:32<00:00,  9.23s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:11<01:44, 11.58s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:31<02:11, 16.45s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:48<01:55, 16.53s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [01:00<01:29, 14.94s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [01:12<01:09, 13.88s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [01:27<00:56, 14.09s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [01:31<00:32, 10.80s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:44<00:23, 11.57s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:47<00:08,  8.99s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:50<00:00, 11.07s/it]
# Global optimization successfully!

# %%
for i in range(1, 4):
    # i = 1
    data_name = "sagittal{}".format(i)
    # data_name = "well_{:02d}".format(i)
    cur_data_folder = os.path.join(data_folder, data_name)
    s = ad.read_h5ad(os.path.join(data_folder, data_name + '.h5ad'))
    slices = [s[s.obs['slice_id'] == str(i)] for i in range(10)]
    key_added = "global_align_spatial"
    global_align_slices = st.align.morpho_global_optimization(
        models=slices,
        spatial_key='align_spatial',
        key_added="global_align_spatial",
        device="3",
        mode="SN-S",
        max_iter_global=5,
        max_iter=200,
        verbose=False,
        partial_robust_level=50,
        beta=1e-4,
        lambdaVF=1e4,
        vis_optimization=False,
        fps=10,
        stepsize=4,
        nn_init=True,
        batch_size=4000,
        nonrigid_idx=None,
        neighbor_size=2,
    )
        
    stacked_slices = ad.concat(global_align_slices, axis=0, label='slice_id')
    stacked_slices.write_h5ad(os.path.join(results_folder, data_name+'.h5ad'))
# Out:
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:02<00:09,  1.16s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:23<01:07,  9.62s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:58<01:53, 18.93s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [01:30<01:56, 23.36s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [02:09<01:54, 28.73s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [02:23<01:11, 23.99s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [02:50<00:49, 24.91s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [03:13<00:24, 24.32s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [03:21<00:00, 20.12s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:35<05:22, 35.88s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:54<03:28, 26.01s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [01:11<02:32, 21.85s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [01:48<02:47, 27.83s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [02:18<02:21, 28.40s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [02:24<01:22, 20.74s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [02:57<01:14, 24.80s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [03:28<00:53, 26.70s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [03:51<00:25, 25.66s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [03:57<00:00, 23.78s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:18<02:43, 18.15s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:40<02:46, 20.79s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [01:28<03:50, 32.89s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [01:45<02:39, 26.65s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 