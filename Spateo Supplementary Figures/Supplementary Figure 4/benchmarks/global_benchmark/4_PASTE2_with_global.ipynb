# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'
import sys
from pathlib import Path
import anndata as ad
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import seaborn as sns
from matplotlib import pyplot as plt

sys.path.insert(0, "/home/ylu/project/spateo-release_new")
import spateo_dev as st
sys.path.insert(0, "/home/ylu/project")
from utils import *
import os

os.system('/usr/bin/Xvfb :99 -screen 0 1024x768x24 &')
os.environ['DISPLAY'] = ':99'

# %load_ext autoreload
# %autoreload 2
# Out:
# 2024-08-17 23:41:42.782863: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-17 23:41:42.951607: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-08-17 23:41:42.951635: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-08-17 23:41:43.660453: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-08-17 23:41:43.660549: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-08-17 23:41:43.660557: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (EE)
# Fatal server error:
# (EE) Server is already active for display 99
# 	If this server is no longer running, remove /tmp/.X99-lock
# 	and start again.
# (EE)

# %%
method_name = 'PASTE2'
# ori_results_folder = ""
data_folder = f"./global_results/{method_name}/"
results_folder = f"./global_results/{method_name}_global/"
if not os.path.exists(results_folder):
    os.mkdir(results_folder)

# %%
for i in range(16):
    # i = 1
    # data_name = "sagittal{}".format(i)
    data_name = "well_{:02d}".format(i)
    cur_data_folder = os.path.join(data_folder, data_name)
    s = ad.read_h5ad(os.path.join(data_folder, data_name + '.h5ad'))
    slices = [s[s.obs['slice_id'] == str(i)] for i in range(10)]
    key_added = "global_align_spatial"
    global_align_slices = st.align.morpho_global_optimization(
        models=slices,
        spatial_key='align_spatial',
        key_added="global_align_spatial",
        device="3",
        mode="SN-S",
        max_iter_global=5,
        max_iter=200,
        verbose=False,
        partial_robust_level=50,
        beta=1e-4,
        lambdaVF=1e4,
        vis_optimization=False,
        fps=10,
        stepsize=4,
        nn_init=True,
        batch_size=4000,
        nonrigid_idx=None,
        neighbor_size=2,
    )
        
    stacked_slices = ad.concat(global_align_slices, axis=0, label='slice_id')
    stacked_slices.write_h5ad(os.path.join(results_folder, data_name+'.h5ad'))
# Out:
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:01<00:04,  1.74it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:02<00:05,  1.18it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:04<00:07,  1.22s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:05<00:06,  1.28s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:07<00:05,  1.45s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:09<00:04,  1.56s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:11<00:03,  1.76s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:12<00:01,  1.68s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:15<00:00,  1.57s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:01<00:16,  1.89s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:03<00:13,  1.66s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:05<00:12,  1.83s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:08<00:14,  2.44s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:10<00:11,  2.21s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:13<00:09,  2.31s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:14<00:06,  2.14s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:17<00:04,  2.29s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:19<00:02,  2.28s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:21<00:00,  2.17s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:02<00:22,  2.48s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:05<00:20,  2.55s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:06<00:13,  1.97s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:08<00:12,  2.00s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:10<00:09,  1.98s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:11<00:06,  1.58s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:12<00:04,  1.48s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:14<00:03,  1.67s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:16<00:01,  1.83s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:19<00:00,  1.93s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:01<00:09,  1.06s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:03<00:12,  1.61s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:05<00:12,  1.81s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:07<00:11,  1.90s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:09<00:09,  1.98s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:12<00:09,  2.30s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:14<00:06,  2.22s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:16<00:04,  2.16s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:18<00:02,  2.28s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:20<00:00,  2.02s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:02<00:18,  2.04s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:04<00:20,  2.55s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:07<00:16,  2.37s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:09<00:14,  2.43s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:12<00:13,  2.65s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:13<00:08,  2.15s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:16<00:07,  2.35s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:18<00:04,  2.28s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:20<00:01,  1.99s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:22<00:00,  2.23s/it]
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
# Global optimization successfully!
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:01<00:04,  1.68it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:03<00:08,  1.19s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:05<00:09,  1.59s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:08<00:09,  1.93s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:10<00:08,  2.22s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:12<00:06,  2.11s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:13<00:03,  1.81s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:15<00:01,  1.89s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:18<00:00,  1.82s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:02<00:21,  2.36s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:04<00:16,  2.10s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:07<00:16,  2.40s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:09<00:14,  2.49s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:12<00:12,  2.46s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:15<00:10,  2.71s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:17<00:07,  2.57s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:19<00:04,  2.41s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:22<00:02,  2.55s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:25<00:00,  2.53s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:03<00:27,  3.01s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:05<00:21,  2.65s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:08<00:19,  2.72s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:10<00:15,  2.58s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:13<00:14,  2.83s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:17<00:12,  3.01s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:20<00:09,  3.07s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:22<00:05,  2.81s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:24<00:02,  2.65s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:26<00:00,  2.69s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:03<00:32,  3.59s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:05<00:22,  2.85s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:08<00:20,  2.87s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:11<00:16,  2.69s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:12<00:11,  2.26s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:14<00:08,  2.15s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:17<00:07,  2.38s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:20<00:04,  2.48s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:22<00:02,  2.36s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:25<00:00,  2.51s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:02<00:23,  2.64s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:05<00:22,  2.79s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:07<00:17,  2.44s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:09<00:13,  2.30s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:12<00:11,  2.35s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:14<00:10,  2.50s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:17<00:07,  2.62s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:20<00:05,  2.77s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:23<00:02,  2.63s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:25<00:00,  2.56s/it]
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# ...
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:23<00:31,  5.19s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:25<00:20,  4.01s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:31<00:19,  4.85s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:34<00:12,  4.06s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:41<00:10,  5.06s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:47<00:05,  5.41s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:49<00:00,  4.95s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:07<01:11,  7.92s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:14<00:54,  6.85s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:21<00:49,  7.06s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:23<00:30,  5.09s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:25<00:20,  4.08s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:31<00:19,  4.80s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:38<00:15,  5.30s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:44<00:11,  5.55s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:46<00:04,  4.42s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:47<00:00,  4.80s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:06<00:56,  6.31s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:12<00:51,  6.44s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:21<00:51,  7.34s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:28<00:44,  7.45s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:30<00:26,  5.40s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:33<00:17,  4.43s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:35<00:10,  3.63s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:41<00:09,  4.56s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:45<00:04,  4.26s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:50<00:00,  5.08s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:01<00:16,  1.84s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:09<00:41,  5.15s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:11<00:28,  4.02s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:13<00:18,  3.01s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:20<00:22,  4.43s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:22<00:14,  3.74s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:30<00:15,  5.11s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:37<00:11,  5.64s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:44<00:06,  6.03s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:46<00:00,  4.69s/it]
# Global optimization successfully!

# %%
for i in range(1, 4):
    # i = 1
    data_name = "sagittal{}".format(i)
    # data_name = "well_{:02d}".format(i)
    cur_data_folder = os.path.join(data_folder, data_name)
    s = ad.read_h5ad(os.path.join(data_folder, data_name + '.h5ad'))
    slices = [s[s.obs['slice_id'] == str(i)] for i in range(10)]
    key_added = "global_align_spatial"
    global_align_slices = st.align.morpho_global_optimization(
        models=slices,
        spatial_key='align_spatial',
        key_added="global_align_spatial",
        device="3",
        mode="SN-S",
        max_iter_global=5,
        max_iter=200,
        verbose=False,
        partial_robust_level=50,
        beta=1e-4,
        lambdaVF=1e4,
        vis_optimization=False,
        fps=10,
        stepsize=4,
        nn_init=True,
        batch_size=4000,
        nonrigid_idx=None,
        neighbor_size=2,
    )
        
    stacked_slices = ad.concat(global_align_slices, axis=0, label='slice_id')
    stacked_slices.write_h5ad(os.path.join(results_folder, data_name+'.h5ad'))
# Out:
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:05<00:21,  2.71s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:12<00:31,  4.49s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:25<00:47,  7.85s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:43<00:56, 11.20s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [01:00<00:53, 13.26s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [01:08<00:34, 11.63s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:22<00:24, 12.26s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:33<00:11, 11.75s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:38<00:00,  9.82s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:08<01:13,  8.22s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:12<00:45,  5.65s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:27<01:11, 10.16s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:35<00:55,  9.31s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:40<00:38,  7.76s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:49<00:32,  8.17s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [01:05<00:32, 10.86s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:14<00:19,  9.99s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:31<00:12, 12.28s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:49<00:00, 10.94s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:03<00:32,  3.56s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:13<00:57,  7.18s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:25<01:04,  9.28s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:37<01:02, 10.34s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:44<00:45,  9.19s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [01:01<00:48, 12.02s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [01:18<00:40, 13.48s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:26<00:23, 11.92s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:34<00:10, 10.59s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:52<00:00, 11.21s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:06<01:02,  6.98s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:15<01:02,  7.82s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:18<00:39,  5.66s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:35<01:00, 10.12s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:39<00:39,  7.83s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:46<00:29,  7.50s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:54<00:23,  7.77s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:02<00:15,  7.90s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:17<00:10, 10.21s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:35<00:00,  9.51s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:18<02:45, 18.42s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:26<01:39, 12.42s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:44<01:44, 14.97s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:51<01:10, 11.80s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:54<00:43,  8.71s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [01:05<00:38,  9.51s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [01:15<00:28,  9.61s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:24<00:18,  9.47s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:42<00:11, 11.98s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:58<00:00, 11.86s/it]
# Global optimization successfully!
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:05<00:22,  2.86s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:11<00:27,  3.90s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:31<01:00, 10.16s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:41<00:50, 10.19s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:53<00:42, 10.67s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [01:01<00:29,  9.90s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:10<00:18,  9.39s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:15<00:07,  8.00s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:20<00:00,  8.04s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:07<01:06,  7.38s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:10<00:40,  5.06s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:17<00:41,  5.90s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:25<00:39,  6.60s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:39<00:45,  9.19s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:46<00:34,  8.69s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:58<00:29,  9.77s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:07<00:19,  9.53s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:12<00:07,  7.89s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:24<00:00,  8.46s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:11<01:42, 11.41s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:19<01:13,  9.21s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:28<01:04,  9.18s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:35<00:49,  8.31s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:43<00:41,  8.23s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:50<00:32,  8.03s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [01:02<00:27,  9.10s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:16<00:21, 10.85s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:20<00:08,  8.76s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:24<00:00,  8.44s/it]
# Early stop the global optimization.
# Global optimization successfully!
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:14<00:57,  7.23s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:26<01:05,  9.36s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:41<01:07, 11.21s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [01:05<01:18, 15.64s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [01:21<01:04, 16.06s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [01:42<00:52, 17.39s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [01:57<00:33, 16.61s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [02:10<00:15, 15.54s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [02:22<00:00, 14.28s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:15<02:19, 15.53s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:31<02:05, 15.69s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:56<02:21, 20.15s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [01:13<01:52, 18.72s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [01:28<01:27, 17.53s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [01:41<01:03, 15.85s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [01:51<00:41, 13.87s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [02:04<00:27, 13.72s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [02:14<00:12, 12.58s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [02:30<00:00, 15.01s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:16<02:26, 16.33s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:25<01:36, 12.11s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:39<01:32, 13.20s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:54<01:21, 13.53s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [01:08<01:09, 13.96s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [01:45<01:27, 21.86s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [01:59<00:57, 19.04s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [02:09<00:32, 16.20s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [02:22<00:15, 15.38s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [02:37<00:00, 15.71s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:13<02:01, 13.51s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:30<02:04, 15.59s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:46<01:49, 15.62s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [01:02<01:34, 15.77s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [01:17<01:17, 15.42s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [01:26<00:54, 13.53s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [02:02<01:01, 20.66s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [02:17<00:38, 19.00s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [02:30<00:17, 17.05s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [02:40<00:00, 16.02s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:16<02:29, 16.65s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:26<01:41, 12.65s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:40<01:31, 13.05s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:53<01:18, 13.07s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [01:02<00:59, 11.90s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [01:40<01:22, 20.68s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [01:56<00:57, 19.01s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [02:10<00:34, 17.41s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [02:24<00:16, 16.44s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [02:39<00:00, 15.94s/it]
# Global optimization successfully!

# %%
s = ad.read_h5ad(os.path.join(results_folder, m, f))
norm_scale = np.linalg.norm(s.obsm['spatial'].max(0) - s.obsm['spatial'].min(0))
if m == 'Spateo_global':
    e = reconstruction_error_3D(s.obsm['global_align_spatial'],s.obsm['spatial'])[0] / norm_scale
