# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'
import sys
from pathlib import Path
import anndata as ad
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import seaborn as sns
from matplotlib import pyplot as plt

sys.path.insert(0, "/home/ylu/project/spateo-release_new")
import spateo_dev as st
sys.path.insert(0, "/home/ylu/project")
from utils import *
import os

os.system('/usr/bin/Xvfb :99 -screen 0 1024x768x24 &')
os.environ['DISPLAY'] = ':99'

# %load_ext autoreload
# %autoreload 2
# Out:
# 2024-08-18 22:08:37.447461: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-18 22:08:37.587417: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-08-18 22:08:37.587451: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-08-18 22:08:38.293647: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-08-18 22:08:38.293747: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-08-18 22:08:38.293755: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (EE)
# Fatal server error:
# (EE) Server is already active for display 99
# 	If this server is no longer running, remove /tmp/.X99-lock
# 	and start again.
# (EE)

# %%
method_name = 'PASTE'
# ori_results_folder = ""
data_folder = f"./global_results/{method_name}/"
results_folder = f"./global_results/{method_name}_global/"
if not os.path.exists(results_folder):
    os.mkdir(results_folder)

# %%
for i in range(1,4):
    # i = 1
    data_name = "sagittal{}".format(i)
    # data_name = "well_{:02d}".format(i)
    cur_data_folder = os.path.join(data_folder, data_name)
    s = ad.read_h5ad(os.path.join(data_folder, data_name + '.h5ad'))
    slices = [s[s.obs['slice_id'] == str(i)] for i in range(10)]
    key_added = "global_align_spatial"
    global_align_slices = st.align.morpho_global_optimization(
        models=slices,
        spatial_key='align_spatial',
        key_added="global_align_spatial",
        device="3",
        mode="SN-S",
        max_iter_global=5,
        max_iter=200,
        verbose=False,
        partial_robust_level=50,
        beta=1e-4,
        lambdaVF=1e4,
        vis_optimization=False,
        fps=10,
        stepsize=4,
        nn_init=True,
        batch_size=4000,
        nonrigid_idx=None,
        neighbor_size=2,
    )
        
    stacked_slices = ad.concat(global_align_slices, axis=0, label='slice_id')
    stacked_slices.write_h5ad(os.path.join(results_folder, data_name+'.h5ad'))

# %%
for i in range(12, 16):
    # i = 1
    # data_name = "sagittal{}".format(i)
    data_name = "well_{:02d}".format(i)
    cur_data_folder = os.path.join(data_folder, data_name)
    s = ad.read_h5ad(os.path.join(data_folder, data_name + '.h5ad'))
    slices = [s[s.obs['slice_id'] == str(i)] for i in range(10)]
    key_added = "global_align_spatial"
    global_align_slices = st.align.morpho_global_optimization(
        models=slices,
        spatial_key='align_spatial',
        key_added="global_align_spatial",
        device="3",
        mode="SN-S",
        max_iter_global=5,
        max_iter=200,
        verbose=False,
        partial_robust_level=50,
        beta=1e-4,
        lambdaVF=1e4,
        vis_optimization=False,
        fps=10,
        stepsize=4,
        nn_init=True,
        batch_size=4000,
        nonrigid_idx=None,
        neighbor_size=2,
    )
        
    stacked_slices = ad.concat(global_align_slices, axis=0, label='slice_id')
    stacked_slices.write_h5ad(os.path.join(results_folder, data_name+'.h5ad'))
# Out:
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
# /home/ylu/project/spateo-release_new/spateo_dev/alignment/morpho_alignment.py:458: ImplicitModificationWarning:
#
# Setting element `.obsm['global_align_spatial']` of view, initializing view as actual.
#
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:03<00:13,  1.66s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:07<00:17,  2.54s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:11<00:18,  3.06s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:18<00:23,  4.71s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:27<00:24,  6.06s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:36<00:21,  7.07s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:44<00:14,  7.19s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [00:53<00:07,  7.73s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:58<00:00,  5.83s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:08<01:16,  8.54s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:17<01:10,  8.84s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:24<00:54,  7.80s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:30<00:44,  7.37s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:39<00:38,  7.73s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:48<00:32,  8.19s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:51<00:19,  6.40s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:57<00:12,  6.46s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:06<00:07,  7.29s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:15<00:00,  7.56s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:04<00:36,  4.10s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:12<00:53,  6.70s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:21<00:54,  7.81s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:30<00:49,  8.23s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:39<00:42,  8.54s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00:47<00:32,  8.20s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  70%|████████████████████████████████████████████████████████████████████████▊                               | 7/10 [00:50<00:19,  6.46s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  80%|███████████████████████████████████████████████████████████████████████████████████▏                    | 8/10 [00:59<00:14,  7.29s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████▌          | 9/10 [01:05<00:07,  7.06s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [01:11<00:00,  7.17s/it]
#   0%|                                                                                                                | 0/10 [00:00<?, ?it/s]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  10%|██████████▍                                                                                             | 1/10 [00:05<00:50,  5.60s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  20%|████████████████████▊                                                                                   | 2/10 [00:13<00:57,  7.13s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  30%|███████████████████████████████▏                                                                        | 3/10 [00:19<00:45,  6.46s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  40%|█████████████████████████████████████████▌                                                              | 4/10 [00:28<00:44,  7.41s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  50%|████████████████████████████████████████████████████                                                    | 5/10 [00:37<00:40,  8.03s/it]/home/ylu/project/spateo-release_new/spateo_dev/alignment/methods/utils.py:1400: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  60%|██████████████████████████████████████████████████████████████▍                                         | 6/10 [00